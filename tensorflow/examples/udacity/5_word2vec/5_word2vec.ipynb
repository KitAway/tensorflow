# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'anarchism', 'term', 'of', 'term', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, 
                               biases=softmax_biases, 
                               inputs=embed,
                               labels=train_labels, 
                               num_sampled=num_sampled, 
                               num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.291622
# Nearest to world: purge, irma, apokryphen, rijndael, assassination, cystitis, jerky, buoyancy,
# Nearest to will: gif, forts, vivre, cohabitation, confederation, roh, insulating, gurevich,
# Nearest to war: raf, antichrist, ung, sdlp, rohe, truro, markup, brl,
# Nearest to to: incubus, cannabis, nepotism, assoc, tutti, protectorates, kuan, hermeneutic,
# Nearest to called: determinant, punks, dnow, fgm, leonel, appliances, specialization, duel,
# Nearest to such: epidemic, blemish, allowable, chee, enhancing, mideast, babbage, paparazzi,
# Nearest to it: cossacks, agitated, boh, segr, regulation, mad, fossils, ecumenical,
# Nearest to four: pile, playoff, strolling, goidelic, vertically, pierluigi, skaldic, czechoslovakia,
# Nearest to used: verrocchio, weasel, taunting, cathari, enactments, howie, conditional, reaffirming,
# Nearest to over: appealed, copula, aleman, braddock, hural, kaliningrad, guinean, heiland,
# Nearest to into: windows, styne, practising, savior, second, reclaim, penguin, novelists,
# Nearest to no: utilize, spells, coder, missourians, agincourt, quintessential, gesenius, printing,
# Nearest to is: hci, mallet, lovelock, superstition, didactic, oratio, dore, zelazny,
# Nearest to eight: spoof, cajun, rance, supersonic, outposts, existence, nieuwe, appel,
# Nearest to many: magus, parastatal, grand, ethiopians, crucifixion, highwayman, minarets, bikini,
# Nearest to are: morphogenesis, rabies, asher, riemann, aronson, nchez, contagion, vines,
# Average loss at step 2000: 4.378152
# Average loss at step 4000: 3.869958
# Average loss at step 6000: 3.791016
# Average loss at step 8000: 3.689415
# Average loss at step 10000: 3.619085
# Nearest to world: purge, assassination, tucked, ideally, gana, vie, truncated, och,
# Nearest to will: roh, cohabitation, understood, sheepdog, credited, can, vivre, earthly,
# Nearest to war: rohe, raf, hippo, salim, ung, summertime, pulls, remedial,
# Nearest to to: would, brightly, incubus, not, riemannian, snoop, seaway, scientologists,
# Nearest to called: punks, summations, reached, anselm, unceasing, dnow, petropavlovsk, original,
# Nearest to such: nonpolar, chee, epidemic, paparazzi, prague, known, mideast, babbage,
# Nearest to it: he, this, there, they, not, that, no, also,
# Nearest to four: six, eight, five, three, seven, two, nine, zero,
# Nearest to used: faux, known, photosynthesis, bnf, seen, advance, archibald, ops,
# Nearest to over: appealed, copula, aleman, kaliningrad, hiroshima, heiland, off, braddock,
# Nearest to into: in, styne, practising, miscellany, penguin, from, tua, savior,
# Nearest to no: quintessential, it, sometimes, venetians, utilize, agincourt, acheson, which,
# Nearest to is: was, are, via, has, be, mallet, islanders, shapes,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to many: some, directed, all, mazzola, particularly, alef, swims, succeed,
# Nearest to are: were, is, have, wlad, ivar, was, could, undisputed,
# Average loss at step 12000: 3.601083
# Average loss at step 14000: 3.572020
# Average loss at step 16000: 3.413941
# Average loss at step 18000: 3.457574
# Average loss at step 20000: 3.546399
# Nearest to world: assassination, ideally, songbook, horseman, randori, gana, truncated, tucked,
# Nearest to will: can, would, may, must, could, to, might, cohabitation,
# Nearest to war: hippo, pulls, rohe, injectors, ung, salim, raf, pinocchio,
# Nearest to to: would, incubus, riemannian, not, camouflage, will, should, scurvy,
# Nearest to called: summations, used, punks, azteca, anselm, reached, original, known,
# Nearest to such: known, nonpolar, these, prague, chee, well, deeper, bondage,
# Nearest to it: he, this, there, which, they, she, not, boar,
# Nearest to four: three, six, eight, five, seven, two, nine, one,
# Nearest to used: known, faux, seen, bnf, called, ops, pig, marco,
# Nearest to over: kaliningrad, appealed, aleman, copula, off, hiroshima, heiland, into,
# Nearest to into: from, miscellany, in, through, styne, practising, andaman, mehr,
# Nearest to no: quintessential, a, which, dalai, there, sometimes, microstates, portrayed,
# Nearest to is: was, are, has, be, were, islanders, but, tristan,
# Nearest to eight: nine, seven, six, four, five, three, two, zero,
# Nearest to many: some, several, all, these, other, succeed, chem, swims,
# Nearest to are: were, is, have, canaveral, was, be, other, philosophic,
# Average loss at step 22000: 3.501664
# Average loss at step 24000: 3.490911
# Average loss at step 26000: 3.485401
# Average loss at step 28000: 3.477296
# Average loss at step 30000: 3.506831
# Nearest to world: assassination, ideally, horseman, randori, songbook, truncated, tucked, abbasid,
# Nearest to will: would, can, may, could, must, might, should, to,
# Nearest to war: pulls, pinocchio, ung, pen, rohe, raf, injectors, canaria,
# Nearest to to: would, incubus, must, kenyon, could, will, can, expropriated,
# Nearest to called: used, summations, aiming, known, aia, considered, reached, punks,
# Nearest to such: these, known, well, nonpolar, soybean, some, having, many,
# Nearest to it: he, this, there, she, they, which, not, commercialize,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to used: known, seen, found, written, described, faux, called, given,
# Nearest to over: off, copula, giulio, aleman, before, into, place, kaliningrad,
# Nearest to into: from, through, miscellany, on, volvo, andaman, styne, in,
# Nearest to no: a, any, armas, there, she, microstates, quintessential, acheson,
# Nearest to is: was, has, are, if, be, were, but, canaveral,
# Nearest to eight: nine, five, six, four, seven, three, zero, two,
# Nearest to many: some, several, these, all, most, other, chem, recent,
# Nearest to are: were, is, have, those, including, canaveral, unacceptably, include,
# Average loss at step 32000: 3.501138
# Average loss at step 34000: 3.493707
# Average loss at step 36000: 3.454260
# Average loss at step 38000: 3.303116
# Average loss at step 40000: 3.424892
# Nearest to world: assassination, randori, capt, horseman, muay, tucked, ideally, ronin,
# Nearest to will: would, can, may, could, must, should, might, did,
# Nearest to war: pinocchio, pulls, rohe, pen, irvine, ung, canaria, trade,
# Nearest to to: must, can, riemannian, will, could, in, scurvy, would,
# Nearest to called: considered, aiming, bishoprics, aia, used, reached, summations, azteca,
# Nearest to such: well, these, known, soybean, nonpolar, many, described, relativist,
# Nearest to it: he, there, she, this, they, which, not, only,
# Nearest to four: six, eight, five, three, seven, two, nine, zero,
# Nearest to used: known, found, seen, given, described, written, referred, faux,
# Nearest to over: off, into, junk, before, giulio, about, copula, bahrain,
# Nearest to into: through, from, miscellany, over, casket, andaman, volvo, snopes,
# Nearest to no: any, armas, jurisdictions, acheson, a, there, it, microstates,
# Nearest to is: was, are, has, be, if, tradeoff, republished, in,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to many: some, several, these, various, those, most, both, nonpolar,
# Nearest to are: were, is, have, be, including, steaming, those, while,
# Average loss at step 42000: 3.432715
# Average loss at step 44000: 3.457206
# Average loss at step 46000: 3.444465
# Average loss at step 48000: 3.358057
# Average loss at step 50000: 3.384350
# Nearest to world: admire, horseman, ideally, holbein, capt, assassination, muay, och,
# Nearest to will: would, can, could, may, must, might, should, shall,
# Nearest to war: pulls, derrick, pinocchio, arctan, emc, trade, canaria, rohe,
# Nearest to to: would, riemannian, seaway, incubus, should, could, marries, can,
# Nearest to called: aiming, named, known, considered, agglomeration, bracing, bishoprics, wilmut,
# Nearest to such: well, these, known, many, soybean, described, having, relativist,
# Nearest to it: he, she, there, this, they, extravagant, still, ellesmere,
# Nearest to four: six, seven, five, eight, three, nine, two, zero,
# Nearest to used: known, seen, written, given, found, referred, described, designed,
# Nearest to over: off, place, giulio, into, about, bahrain, junk, through,
# Nearest to into: through, from, miscellany, ziggy, mortis, volvo, around, over,
# Nearest to no: any, wikibooks, she, armas, a, trilemma, jurisdictions, sophisticated,
# Nearest to is: was, are, has, became, republished, be, manipulates, contains,
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to many: some, several, these, various, those, both, most, such,
# Nearest to are: were, is, have, informers, those, be, include, although,
# Average loss at step 52000: 3.439748
# Average loss at step 54000: 3.423094
# Average loss at step 56000: 3.434351
# Average loss at step 58000: 3.398251
# Average loss at step 60000: 3.395018
# Nearest to world: horseman, ideally, assassination, holbein, civil, muay, admire, biscuit,
# Nearest to will: would, could, can, may, must, should, might, did,
# Nearest to war: canaria, derrick, pulls, irritant, prohibits, arctan, pinocchio, ung,
# Nearest to to: would, energized, incubus, should, lana, scurvy, will, courses,
# Nearest to called: considered, used, named, referred, known, wilmut, bracing, aiming,
# Nearest to such: these, having, known, well, many, described, some, ipswich,
# Nearest to it: he, this, she, there, they, which, boar, what,
# Nearest to four: six, five, eight, three, seven, nine, two, zero,
# Nearest to used: known, written, referred, seen, found, designed, given, described,
# Nearest to over: into, through, off, throughout, about, junk, around, place,
# Nearest to into: through, from, over, miscellany, around, andaman, ziggy, within,
# Nearest to no: any, armas, wikibooks, she, incompatible, sophisticated, abdallah, balloting,
# Nearest to is: was, are, has, be, although, became, if, but,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to many: some, several, these, all, various, most, both, those,
# Nearest to are: were, is, have, those, include, transformers, including, although,
# Average loss at step 62000: 3.238473
# Average loss at step 64000: 3.254974
# Average loss at step 66000: 3.405637
# Average loss at step 68000: 3.393266
# Average loss at step 70000: 3.360296
# Nearest to world: assassination, horseman, holbein, biscuit, disbelief, admire, muay, ideally,
# Nearest to will: would, can, could, may, must, should, might, shall,
# Nearest to war: wars, arctan, irritant, battle, pinocchio, derrick, emc, swimmer,
# Nearest to to: will, would, riemannian, incubus, must, can, should, energized,
# Nearest to called: named, considered, referred, used, bracing, known, flavored, elton,
# Nearest to such: these, well, known, many, described, follows, ipswich, having,
# Nearest to it: he, she, there, this, they, normally, which, we,
# Nearest to four: five, six, three, eight, seven, nine, two, zero,
# Nearest to used: known, written, referred, found, seen, designed, available, described,
# Nearest to over: around, about, junk, place, off, giulio, ts, heiland,
# Nearest to into: through, from, miscellany, volvo, andaman, within, vg, out,
# Nearest to no: any, incompatible, sophisticated, she, compared, wikibooks, armas, only,
# Nearest to is: was, has, are, be, becomes, seems, although, republished,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to many: some, several, all, most, these, various, such, both,
# Nearest to are: were, is, have, informers, these, include, transformers, although,
# Average loss at step 72000: 3.371657
# Average loss at step 74000: 3.349271
# Average loss at step 76000: 3.318778
# Average loss at step 78000: 3.354068
# Average loss at step 80000: 3.379800
# Nearest to world: horseman, assassination, holbein, biscuit, alomari, librarians, muay, ideally,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to war: wars, derrick, arctan, irritant, prohibits, pinocchio, irvine, epicureanism,
# Nearest to to: will, should, riemannian, cadbury, incubus, seaway, marries, would,
# Nearest to called: named, considered, known, referred, used, unmolested, motala, wilmut,
# Nearest to such: these, well, follows, known, stag, ipswich, soybean, opposed,
# Nearest to it: he, she, there, this, they, never, we, not,
# Nearest to four: six, five, seven, eight, three, two, nine, zero,
# Nearest to used: known, written, referred, seen, found, given, designed, described,
# Nearest to over: around, within, throughout, off, into, about, through, before,
# Nearest to into: through, from, vg, within, onto, volvo, around, casket,
# Nearest to no: any, incompatible, wikibooks, little, she, budgetary, alienating, langerhans,
# Nearest to is: was, has, are, republished, became, were, be, iata,
# Nearest to eight: nine, six, seven, five, four, three, zero, one,
# Nearest to many: some, several, various, most, these, all, both, few,
# Nearest to are: were, is, have, include, although, informers, these, those,
# Average loss at step 82000: 3.409045
# Average loss at step 84000: 3.409933
# Average loss at step 86000: 3.389889
# Average loss at step 88000: 3.355494
# Average loss at step 90000: 3.366230
# Nearest to world: horseman, disbelief, assassination, holbein, importance, ideally, biscuit, capt,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to war: wars, irritant, derrick, prohibits, varese, battle, canaria, alicante,
# Nearest to to: would, riemannian, incubus, scurvy, will, towards, ozark, could,
# Nearest to called: named, referred, considered, used, known, unmolested, motala, fungus,
# Nearest to such: well, these, known, follows, soybean, stag, described, many,
# Nearest to it: he, she, there, this, they, never, we, which,
# Nearest to four: five, eight, seven, six, three, two, nine, zero,
# Nearest to used: known, seen, referred, designed, written, found, given, called,
# Nearest to over: around, within, off, about, greatly, ts, through, killers,
# Nearest to into: through, from, around, volvo, out, casket, onto, vg,
# Nearest to no: any, little, langerhans, completely, only, always, northerly, masturbating,
# Nearest to is: was, are, has, be, refers, becomes, became, although,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,
# Nearest to many: several, some, various, these, all, most, both, few,
# Nearest to are: were, is, include, have, these, informers, although, transformers,
# Average loss at step 92000: 3.399723
# Average loss at step 94000: 3.251695
# Average loss at step 96000: 3.358101
# Average loss at step 98000: 3.248036
# Average loss at step 100000: 3.352122
# Nearest to world: horseman, disbelief, muay, country, capt, pero, holbein, ronin,
# Nearest to will: would, can, could, must, should, may, might, cannot,
# Nearest to war: wars, irritant, battle, derrick, canaria, epicureanism, swimmer, liberties,
# Nearest to to: could, would, will, should, can, incubus, must, towards,
# Nearest to called: named, referred, known, draped, used, considered, unmolested, and,
# Nearest to such: known, well, these, opposed, described, follows, many, depicted,
# Nearest to it: he, she, there, this, they, never, what, normally,
# Nearest to four: five, six, seven, eight, three, two, nine, zero,
# Nearest to used: referred, known, written, designed, found, seen, given, considered,
# Nearest to over: around, within, off, ts, through, editable, stg, bayezid,
# Nearest to into: through, from, within, onto, around, miscellany, with, out,
# Nearest to no: any, little, incompatible, wikibooks, only, another, langerhans, discontinued,
# Nearest to is: was, has, became, are, refers, becomes, seems, be,
# Nearest to eight: nine, seven, four, six, five, three, zero, two,
# Nearest to many: some, several, these, various, numerous, few, all, most,
# Nearest to are: were, have, although, is, be, those, these, include,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  #assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size,1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    labels[i] = buffer[skip_window]
    bat = np.ndarray(shape=(num_skips), dtype=np.int32)
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
  #    batch[i * num_skips + j] = buffer[skip_window]
  #    labels[i * num_skips + j, 0] = buffer[target]
      bat[j] = buffer[target]
    batch[i,:] = bat
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

showSize = 8
print('data:', [reverse_dictionary[di] for di in data[:showSize+4]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=showSize, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch] )
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(showSize)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['a', 'originated'], ['as', 'term'], ['a', 'of'], ['abuse', 'term'], ['of', 'first'], ['used', 'abuse'], ['against', 'first']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['a', 'term', 'anarchism', 'originated'], ['of', 'originated', 'as', 'term'], ['a', 'as', 'abuse', 'of'], ['first', 'abuse', 'a', 'term'], ['used', 'term', 'of', 'first'], ['abuse', 'used', 'of', 'against'], ['first', 'against', 'early', 'abuse'], ['early', 'working', 'used', 'first']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 2 # How many words to consider left and right.
num_skips = 4 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_skips])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  means = tf.reduce_mean(embed, axis=1)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, 
                               biases=softmax_biases, 
                               inputs=means,
                               labels=train_labels, 
                               num_sampled=num_sampled, 
                               num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
#    print(batch_data.shape)
#    print(batch_labels.shape)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.874374
# Nearest to over: sill, parodies, wheeler, grindcore, usher, rightness, katherine, wanda,
# Nearest to used: eleazar, polled, afp, auditorium, routinely, infectious, rgya, previously,
# Nearest to th: forged, latina, haunting, ebenezer, aide, roc, amalthea, maize,
# Nearest to all: dysfunction, ssy, hydroponic, kites, bentsen, magdalena, dominate, schwarzschild,
# Nearest to new: eoin, cytokines, buses, ym, newfound, xico, pious, tornado,
# Nearest to history: kickstart, lauren, herbicides, interpretative, toward, kune, jolley, assembler,
# Nearest to these: jongg, unfolded, realtime, screw, quarrel, cake, aonb, grandiose,
# Nearest to s: mentioned, mythical, notches, mundi, suiko, carthaginian, bombed, cdot,
# Nearest to united: dictating, infraorder, heater, through, baja, ann, barbosa, albany,
# Nearest to system: asymmetry, symbolised, blaise, subspace, spokes, rockstar, witbrock, inductance,
# Nearest to however: medicaid, nuovo, glorantha, harrier, inches, schwa, monarchies, hyundai,
# Nearest to there: wilbur, englewood, cara, transjordan, instincts, bhfuil, subsidiary, cognate,
# Nearest to most: sina, trilemma, mille, vegetables, privatised, asleep, nunavut, roth,
# Nearest to world: unauthorised, handfasting, criss, tlatelolco, vocalization, coffins, catapulted, restrictions,
# Nearest to has: ascribes, laurence, resemblance, covers, giving, rez, atlantans, perspectives,
# Nearest to three: tomatoes, defensively, seven, salle, exploded, duty, nomination, evergreen,
# Average loss at step 2000: 4.022009
# Average loss at step 4000: 3.568811
# Average loss at step 6000: 3.482327
# Average loss at step 8000: 3.430665
# Average loss at step 10000: 3.308007
# Nearest to over: inspecting, rightness, oireachtas, virtuosic, wheeler, sta, katherine, grindcore,
# Nearest to used: eleazar, polled, bolshevism, handily, coordinate, routinely, contraband, textrm,
# Nearest to th: amplitudes, hermeneutic, haunting, ebenezer, aide, maize, fsm, amalthea,
# Nearest to all: tabled, danse, dysfunction, several, ml, high, denigrating, instead,
# Nearest to new: festivals, buses, cytokines, newfound, wilmington, mulhouse, eoin, hateful,
# Nearest to history: kickstart, europe, lauren, invents, khair, fluctuating, lpg, barker,
# Nearest to these: screw, jongg, realtime, mnemonics, pollutant, hacker, unfolded, maasai,
# Nearest to s: her, crunch, pleading, offutt, meshed, gettier, eagle, withdrawing,
# Nearest to united: early, infraorder, albany, heater, baja, emerson, dictating, thunderbolt,
# Nearest to system: blaise, asymmetry, spokes, symbolised, subspace, vibrato, witbrock, differentiated,
# Nearest to however: medicaid, japanese, nuovo, cit, inches, but, neues, teodoro,
# Nearest to there: very, usually, neutral, austria, wilbur, ulyanov, mistral, plunged,
# Nearest to most: sina, roth, mem, hazards, mononobe, privatised, vegetables, conversant,
# Nearest to world: criss, war, nerd, morton, gap, unauthorised, lle, restrictions,
# Nearest to has: had, have, was, is, covers, apocrypha, breed, endangered,
# Nearest to three: seven, four, six, eight, two, regulations, nine, bosniaks,
# Average loss at step 12000: 3.324188
# Average loss at step 14000: 3.280427
# Average loss at step 16000: 3.275259
# Average loss at step 18000: 3.166523
# Average loss at step 20000: 3.054055
# Nearest to over: grindcore, virtuosic, inspecting, oireachtas, rightness, sta, haer, cheerleaders,
# Nearest to used: known, found, infectious, considered, eleazar, written, trammell, polled,
# Nearest to th: amplitudes, ebenezer, haunting, hermeneutic, fsm, amalthea, aide, maize,
# Nearest to all: many, several, tabled, some, films, dysfunction, instead, any,
# Nearest to new: festivals, wilmington, cytokines, buses, newfound, eoin, affairs, henry,
# Nearest to history: europe, kickstart, fluctuating, toward, head, lx, lauren, unsubstantiated,
# Nearest to these: some, other, many, usaid, intensify, different, screw, various,
# Nearest to s: her, his, eagle, meshed, pleading, countable, hitchhiker, crunch,
# Nearest to united: albany, heater, baja, infraorder, early, encapsulation, emerson, dictating,
# Nearest to system: blaise, asymmetry, spokes, reestablishment, subspace, vibrato, inaction, symbolised,
# Nearest to however: but, inches, cit, medicaid, although, sungorus, thoughtful, though,
# Nearest to there: very, usually, available, mistral, neutral, ulyanov, santander, plunged,
# Nearest to most: many, roth, sina, some, mem, more, hazards, formal,
# Nearest to world: criss, gap, morton, restrictions, rutger, nerd, fidesz, unauthorised,
# Nearest to has: had, have, was, torch, indicates, is, endangered, having,
# Nearest to three: seven, four, six, five, two, eight, mamadou, zero,
# Average loss at step 22000: 3.129351
# Average loss at step 24000: 3.176300
# Average loss at step 26000: 3.093166
# Average loss at step 28000: 3.127268
# Average loss at step 30000: 3.171209
# Nearest to over: grindcore, virtuosic, oireachtas, haer, cheerleaders, about, inspecting, annexes,
# Nearest to used: known, written, found, interpreted, interested, compared, considered, infectious,
# Nearest to th: amplitudes, ebenezer, fsm, haunting, hermeneutic, amalthea, aide, nine,
# Nearest to all: many, several, some, instead, films, tabled, any, dysfunction,
# Nearest to new: wilmington, buses, festivals, eoin, falcons, affairs, newfound, cytokines,
# Nearest to history: europe, music, society, herbicides, palermo, rica, fluctuating, survey,
# Nearest to these: different, other, various, some, many, kr, usaid, intensify,
# Nearest to s: her, his, eagle, meshed, gnat, chemotherapeutic, freitas, dreaming,
# Nearest to united: baja, albany, heater, infraorder, emerson, encapsulation, dns, thunderbolt,
# Nearest to system: asymmetry, blaise, quantrill, spokes, symbolised, subspace, differentiated, reestablishment,
# Nearest to however: although, but, though, while, inches, medicaid, cit, thoughtful,
# Nearest to there: available, ulyanov, numbering, fairly, plunged, neutral, mistral, hybrid,
# Nearest to most: some, many, more, roth, mem, sina, jarre, slipping,
# Nearest to world: criss, gap, restrictions, fidesz, morton, rutger, apprehend, handfasting,
# Nearest to has: had, have, was, having, is, indicates, torch, saw,
# Nearest to three: four, seven, six, five, eight, two, connectors, aggressively,
# Average loss at step 32000: 3.095597
# Average loss at step 34000: 3.042909
# Average loss at step 36000: 3.081004
# Average loss at step 38000: 2.923963
# Average loss at step 40000: 3.051337
# Nearest to over: grindcore, virtuosic, conservatism, oireachtas, inspecting, belgrade, styne, annexes,
# Nearest to used: found, referred, known, written, interested, compared, considered, interpreted,
# Nearest to th: ebenezer, fsm, amplitudes, haunting, amalthea, forged, hermeneutic, spamming,
# Nearest to all: many, several, various, films, instead, some, deflect, every,
# Nearest to new: wilmington, buses, festivals, falcons, warhead, hateful, eoin, nicole,
# Nearest to history: europe, music, society, life, schools, gwynedd, journal, lx,
# Nearest to these: other, various, different, kr, peachtree, intensify, many, some,
# Nearest to s: his, her, freitas, gnat, stowe, eagle, directives, pleading,
# Nearest to united: baja, heater, albany, dns, emerson, infraorder, encapsulation, episcopalian,
# Nearest to system: systems, blaise, asymmetry, subspace, spokes, symbolised, lux, rockstar,
# Nearest to however: but, although, while, though, medicaid, cit, inches, pacemaker,
# Nearest to there: it, fairly, numbering, ulyanov, plunged, largely, sow, available,
# Nearest to most: some, many, more, roth, mem, both, among, best,
# Nearest to world: criss, fidesz, gap, daily, restrictions, rutger, unauthorised, handfasting,
# Nearest to has: had, have, having, is, was, indicates, includes, torch,
# Nearest to three: four, seven, six, five, eight, two, zero, dimensionless,
# Average loss at step 42000: 3.016622
# Average loss at step 44000: 3.050994
# Average loss at step 46000: 3.061060
# Average loss at step 48000: 2.922557
# Average loss at step 50000: 3.034533
# Nearest to over: grindcore, virtuosic, whenever, belgrade, conservatism, cheerleaders, oireachtas, styne,
# Nearest to used: found, referred, written, interested, known, considered, compared, interpreted,
# Nearest to th: fsm, ebenezer, amplitudes, st, nd, haunting, calamities, twentieth,
# Nearest to all: various, several, many, every, instead, deflect, downside, tanks,
# Nearest to new: buses, wilmington, falcons, brief, nicole, warhead, festivals, lorenz,
# Nearest to history: europe, society, journal, music, art, lx, gwynedd, fluctuating,
# Nearest to these: various, different, other, some, many, usaid, kr, contingency,
# Nearest to s: his, her, gnat, freitas, eagle, hitchhiker, isbn, stowe,
# Nearest to united: albany, baja, heater, dns, episcopalian, dictating, infraorder, encapsulation,
# Nearest to system: systems, blaise, inaction, asymmetry, dojo, spokes, bodleian, numeration,
# Nearest to however: but, although, though, while, that, medicaid, sungorus, pacemaker,
# Nearest to there: fairly, they, it, ulyanov, bothnian, pollutant, plunged, available,
# Nearest to most: some, more, many, roth, mem, among, both, best,
# Nearest to world: criss, fidesz, handfasting, daily, rutger, restrictions, morton, gap,
# Nearest to has: had, have, having, is, indicates, was, ce, includes,
# Nearest to three: four, six, seven, five, two, eight, zero, fsm,
# Average loss at step 52000: 3.029801
# Average loss at step 54000: 3.021053
# Average loss at step 56000: 2.996631
# Average loss at step 58000: 3.010539
# Average loss at step 60000: 2.958276
# Nearest to over: grindcore, virtuosic, whenever, through, musicologists, jul, belgrade, cheerleaders,
# Nearest to used: referred, interested, written, found, interpreted, considered, known, available,
# Nearest to th: fsm, ebenezer, nd, twentieth, amplitudes, st, haunting, calamities,
# Nearest to all: various, many, every, several, some, any, both, downside,
# Nearest to new: buses, falcons, brief, wilmington, nicole, warhead, kish, festivals,
# Nearest to history: europe, art, society, style, flickering, journal, music, palermo,
# Nearest to these: various, different, other, some, many, which, peachtree, usaid,
# Nearest to s: his, isbn, gnat, mov, eagle, stowe, freitas, her,
# Nearest to united: albany, heater, baja, dns, infraorder, pleads, conflict, episcopalian,
# Nearest to system: systems, blaise, inaction, model, inspectors, quantrill, dojo, spokes,
# Nearest to however: although, but, while, though, that, sungorus, vannevar, medicaid,
# Nearest to there: they, fairly, it, bothnian, ulyanov, santander, cordite, plunged,
# Nearest to most: some, many, more, roth, best, mem, among, both,
# Nearest to world: criss, fidesz, handfasting, daily, unauthorised, gap, club, rutger,
# Nearest to has: have, had, having, is, indicates, describes, makes, was,
# Nearest to three: four, six, five, two, seven, eight, several, marathon,
# Average loss at step 62000: 2.826037
# Average loss at step 64000: 2.964496
# Average loss at step 66000: 2.953179
# Average loss at step 68000: 2.933524
# Average loss at step 70000: 2.975393
# Nearest to over: jul, grindcore, tripoli, belgrade, virtuosic, subsequently, whenever, cheerleaders,
# Nearest to used: referred, interested, found, written, known, seen, interpreted, available,
# Nearest to th: fsm, nd, ebenezer, st, amplitudes, twentieth, calamities, haunting,
# Nearest to all: various, many, every, several, some, both, any, deflect,
# Nearest to new: buses, brief, falcons, wilmington, nicole, warhead, single, kish,
# Nearest to history: flickering, art, journal, palermo, europe, pasadena, style, life,
# Nearest to these: various, different, other, those, which, peachtree, additional, recipients,
# Nearest to s: his, whose, gnat, isbn, eagle, ardal, fundraiser, ballistic,
# Nearest to united: albany, heater, baja, infraorder, dns, dictating, pleads, us,
# Nearest to system: systems, bodleian, model, technique, blaise, inspectors, quantrill, dojo,
# Nearest to however: although, but, while, though, that, sungorus, medicaid, where,
# Nearest to there: fairly, ulyanov, it, plunged, they, bothnian, kept, amedeo,
# Nearest to most: more, some, many, best, mem, roth, motivations, among,
# Nearest to world: fidesz, criss, handfasting, unauthorised, club, rutger, gap, minicomputers,
# Nearest to has: had, have, having, is, indicates, describes, makes, includes,
# Nearest to three: four, six, five, seven, two, eight, marathon, zero,
# Average loss at step 72000: 2.997423
# Average loss at step 74000: 2.948023
# Average loss at step 76000: 2.954560
# Average loss at step 78000: 2.905908
# Average loss at step 80000: 2.894342
# Nearest to over: jul, whenever, tripoli, grindcore, virtuosic, cheerleaders, belgrade, through,
# Nearest to used: referred, interested, seen, found, interpreted, known, written, compared,
# Nearest to th: nd, fsm, st, ebenezer, twentieth, amplitudes, nineteenth, calamities,
# Nearest to all: various, many, every, several, some, any, both, tanks,
# Nearest to new: buses, brief, falcons, wilmington, nicole, warhead, kish, single,
# Nearest to history: flickering, journal, survey, art, pasadena, society, palermo, boyle,
# Nearest to these: various, different, which, other, additional, peachtree, those, several,
# Nearest to s: his, her, gnat, isbn, tolbert, whose, my, stowe,
# Nearest to united: confederate, albany, heater, baja, pleads, episcopalian, infraorder, dictating,
# Nearest to system: systems, model, inspectors, bodleian, toei, quantrill, technique, maeterlinck,
# Nearest to however: although, but, while, though, that, medicaid, where, flex,
# Nearest to there: fairly, it, ulyanov, plunged, cordite, they, kept, invites,
# Nearest to most: more, many, some, best, roth, less, among, mem,
# Nearest to world: criss, fidesz, handfasting, unauthorised, pessoa, rutger, club, auctions,
# Nearest to has: had, have, having, describes, is, indicates, makes, includes,
# Nearest to three: four, five, six, seven, eight, two, zero, nukem,
# Average loss at step 82000: 2.904679
# Average loss at step 84000: 2.938498
# Average loss at step 86000: 2.804756
# Average loss at step 88000: 2.898484
# Average loss at step 90000: 2.892193
# Nearest to over: whenever, tripoli, jul, grindcore, cheerleaders, virtuosic, through, ep,
# Nearest to used: referred, seen, interpreted, interested, designed, found, described, known,
# Nearest to th: nd, st, fsm, twentieth, nineteenth, ebenezer, calamities, amplitudes,
# Nearest to all: many, various, every, some, several, both, locally, pn,
# Nearest to new: buses, brief, nicole, falcons, wilmington, kish, eoin, adherent,
# Nearest to history: journal, life, europe, art, society, flickering, style, pasadena,
# Nearest to these: various, different, which, those, other, peachtree, additional, several,
# Nearest to s: his, her, whose, my, tolbert, offutt, eagle, chemotherapeutic,
# Nearest to united: confederate, albany, heater, baja, us, dictating, episcopalian, pleads,
# Nearest to system: systems, model, quantrill, technique, inspectors, bodleian, neuropsychological, maeterlinck,
# Nearest to however: although, but, while, though, that, medicaid, theological, endure,
# Nearest to there: fairly, they, ulyanov, plunged, cordite, it, humbucker, kept,
# Nearest to most: more, many, some, best, among, less, roth, motivations,
# Nearest to world: criss, fidesz, handfasting, hillsides, unauthorised, pessoa, auctions, apprehend,
# Nearest to has: had, have, having, describes, indicates, is, includes, makes,
# Nearest to three: four, five, six, seven, two, eight, zero, marathon,
# Average loss at step 92000: 2.869597
# Average loss at step 94000: 2.827017
# Average loss at step 96000: 2.770742
# Average loss at step 98000: 2.826648
# Average loss at step 100000: 2.906589
# Nearest to over: tripoli, whenever, jul, through, grindcore, cheerleaders, virtuosic, under,
# Nearest to used: referred, seen, interested, found, designed, interpreted, described, available,
# Nearest to th: nd, st, nineteenth, twentieth, fsm, nine, ebenezer, fifth,
# Nearest to all: many, various, both, every, several, some, locally, deflect,
# Nearest to new: brief, buses, nicole, falcons, wilmington, kish, psychomotor, warhead,
# Nearest to history: journal, art, origin, society, life, traces, style, era,
# Nearest to these: various, different, those, which, other, several, peachtree, additional,
# Nearest to s: his, whose, gnat, chemotherapeutic, isbn, webern, her, freitas,
# Nearest to united: confederate, albany, heater, baja, us, episcopalian, dictating, infraorder,
# Nearest to system: systems, model, inspectors, maeterlinck, technique, quantrill, network, dojo,
# Nearest to however: although, but, while, though, that, because, cunning, snp,
# Nearest to there: fairly, it, they, cordite, ulyanov, longer, invites, plunged,
# Nearest to most: more, many, some, less, best, among, motivations, mem,
# Nearest to world: criss, fidesz, handfasting, unauthorised, auctions, hillsides, rutger, pessoa,
# Nearest to has: had, have, having, indicates, makes, describes, includes, gives,
# Nearest to three: five, four, six, seven, two, eight, zero, fordham,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
